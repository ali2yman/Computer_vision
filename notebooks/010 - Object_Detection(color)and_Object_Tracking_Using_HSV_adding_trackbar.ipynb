# %%
import cv2
import numpy as np
import os 
os.chdir(r"C:\Users\aliay\OneDrive\Desktop\py_test\computer vision\dataset")

# %%
from cv2 import inRange


while(True):
    frame = cv2.imread("smarties.jpg")
    hsv = cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)

    # the lower and upper value for the color we want to make detection for it (range)
    l_b = np.array([56,88,56])
    u_b = np.array([120,255,255])
    
    # we make this mask (binary_img) to make a thershold >> only the range u give it will be white and the other pixels will be black
    mask = cv2.inRange(hsv,l_b,u_b)
    # (img1,img2,mask)
    res = cv2.bitwise_and(frame,frame,mask=mask)

    cv2.imshow("frame",frame)
    cv2.imshow("mask",mask)
    cv2.imshow('res',res)

    k = cv2.waitKey(0)
    if k == 27:
        break
cv2.destroyAllWindows()

# %% [markdown]
# By Using Trackbar

# %%
def nothing(x):
    print(x)

cv2.namedWindow("Tracking")

# start from 0 
cv2.createTrackbar("LH" , 'Tracking' , 0 , 255 , nothing)  #lower hue
cv2.createTrackbar("LS" , 'Tracking' , 0 , 255 , nothing)  #lower saturation
cv2.createTrackbar("LV" , 'Tracking' , 0 , 255 , nothing)  #lower value
# start from 255
cv2.createTrackbar('UH' , 'Tracking' , 255 , 255 , nothing) #high hue
cv2.createTrackbar('US' , 'Tracking' , 255 , 255 , nothing) #high saturation
cv2.createTrackbar('UV' , 'Tracking' , 255 , 255 , nothing) #high value      

while True:
    frame = cv2.imread("smarties.jpg")
    hsv = cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)

    l_h = cv2.getTrackbarPos('LH','Tracking')
    l_s = cv2.getTrackbarPos('LS','Tracking')
    l_v = cv2.getTrackbarPos('LV','Tracking')

    u_h = cv2.getTrackbarPos('UH','Tracking')
    u_s = cv2.getTrackbarPos('US','Tracking')
    u_v = cv2.getTrackbarPos('UV','Tracking')

    l_b = np.array([l_h,l_s,l_v])
    u_b = np.array([u_h,u_s,u_v])

    mask = cv2.inRange(hsv,l_b,u_b)
    # (img1,img2,mask)
    res = cv2.bitwise_and(frame,frame,mask=mask)

    cv2.imshow("frame",frame)
    cv2.imshow("mask",mask)
    cv2.imshow('res',res)

    k = cv2.waitKey(1)
    if k == 27:
        break
cv2.destroyAllWindows()
# Out:
# 255
# 255
# 255
# 9
# 17
# 26
# 35
# 40
# 45
# 49
# 50
# 52
# 54
# 56
# 57
# 59
# 61
# 62
# 66
# 69
# 76
# 83
# 94
# 99
# 102
# 106
# 108
# 111
# 113
# 114
# 116
# 120
# 121
# 123
# 125
# 127
# 128
# 130
# 132
# 134
# 135
# 137
# 139
# 141
# 142
# 144
# 146
# 147
# 146
# 144
# 142
# 141
# 139
# 137
# 135
# 134
# 132
# 130
# 128
# 127
# 125
# 123
# 121
# 120
# 118
# 116
# 114
# 113
# 111
# 109
# 108
# 106
# 104
# 102
# 101
# 102
# 104
# 106
# 108
# 109
# 111
# 113
# 114
# 116
# 118
# 120
# 69
# 18
# 69
# 68
# 64
# 61
# 57
# 52
# 45
# 40
# 33
# 28
# 23
# 19
# 14
# 12
# 9
# 7
# 3
# 0
# 2
# 3
# 5
# 7
# 9
# 10
# 12
# 14
# 16
# 17
# 19
# 21
# 23
# 24
# 26
# 28
# 29
# 31
# 33
# 35
# 36
# 38
# 40
# 42
# 43
# 45
# 47
# 49
# 50
# 52
# 54
# 56
# 57
# 59
# 61
# 62
# 64
# 66
# 68
# 69
# 71
# 73
# 75
# 76
# 78
# 80
# 82
# 83
# 85
# 87
# 88
# 90
# 92
# 94
# 95
# 97
# 99
# 101
# 102
# 104
# 106
# 108
# 109
# 111
# 113
# 114
# 116
# 118
# 120
# 121
# 120
# 118
# 116
# 114
# 113
# 111
# 109
# 108
# ...

# %% [markdown]
# Doing it with video (Using the main Camera)

# %%
def nothing(x):
    print(x)

cv2.namedWindow("Tracking")

cv2.createTrackbar("LH" , 'Tracking' , 0 , 255 , nothing)  #lower hue
cv2.createTrackbar("LS" , 'Tracking' , 0 , 255 , nothing)  #lower saturation
cv2.createTrackbar("LV" , 'Tracking' , 0 , 255 , nothing)  #lower value
cv2.createTrackbar('UH' , 'Tracking' , 255 , 255 , nothing) #high hue
cv2.createTrackbar('US' , 'Tracking' , 255 , 255 , nothing) #high saturation
cv2.createTrackbar('UV' , 'Tracking' , 255 , 255 , nothing) #high value      

cap = cv2.VideoCapture(0)

while True:
    _,frame = cap.read()
    hsv = cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)

    l_h = cv2.getTrackbarPos('LH','Tracking')
    l_s = cv2.getTrackbarPos('LS','Tracking')
    l_v = cv2.getTrackbarPos('LV','Tracking')

    u_h = cv2.getTrackbarPos('UH','Tracking')
    u_s = cv2.getTrackbarPos('US','Tracking')
    u_v = cv2.getTrackbarPos('UV','Tracking')

    l_b = np.array([l_h,l_s,l_v])
    u_b = np.array([u_h,u_s,u_v])

    mask = cv2.inRange(hsv,l_b,u_b)
    # (img1,img2,mask)
    res = cv2.bitwise_and(frame,frame,mask=mask)

    cv2.imshow("frame",frame)
    cv2.imshow("mask",mask)
    cv2.imshow('res',res)

    k = cv2.waitKey(1)
    if k == 27:
        break
cap.release    
cv2.destroyAllWindows()
# Out:
# 255
# 255
# 255
# 9
# 64
# 66
# 68
# 71
# 73
# 75
# 76
# 78
# 82
# 83
# 85
# 87
# 88
# 90
# 51
# 102
# 51
# 102
# 153
# 85
# 83
# 78
# 76
# 75
# 73
# 75
# 99
# 97
# 95
# 92
# 90
# 88
# 87
# 85
# 83
# 82
# 80
# 83
# 78
# 76
# 75
# 76
# 78
# 82
# 85
# 90
# 92
# 90
# 88
# 87
# 85
# 83
# 82
# 73
# 69
# 68
# 66
# 64
# 61
# 59
# 61
# 62
# 61
# 59
# 57
# 56
# 102
# 101
# 95
# 94
# 90
# 88
# 87
# 85
# 83
# 82
# 80
# 78
# 76
# 75
# 73
# 71
# 69
# 68
# 66
# 64
# 62
# 61
# 59
# 250
# 245
# 232
# 227
# 224
# 219
# 217
# 212
# 206
# 205
# 198
# 196
# 194
# 193
# 189
# 184
# 177
# 170
# 168
# 167
# 165
# 163
# 161
# 154
# 153
# 144
# 135
# 132
# 130
# 127
# 125
# 123
# 120
# 118
# 116
# 114
# 116
# 118
# 120
# 121
# 123
# 125
# 127
